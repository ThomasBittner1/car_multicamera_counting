# %%
import torch
from ultralytics import YOLO
import cv2

# %%
import run
import importlib
importlib.reload(run)
run.run()
# Out:
# SUCCESS  | OcSort: det_thresh=0.3, max_age=30, max_obs=50, min_hits=3, iou_threshold=0.3, per_class=False, asso_func=iou, min_conf=0.1, delta_t=3, inertia=0.2, use_byte=False, Q_xy_scaling=0.01, Q_s_scaling=0.0001
# SUCCESS  | OcSort: det_thresh=0.3, max_age=30, max_obs=50, min_hits=3, iou_threshold=0.3, per_class=False, asso_func=iou, min_conf=0.1, delta_t=3, inertia=0.2, use_byte=False, Q_xy_scaling=0.01, Q_s_scaling=0.0001

# %%
import boxmot
print(boxmot.__file__)
print(dir(boxmot))
# Out:
# C:\ComputerVision\car_multicamera_counting\.venv\lib\site-packages\boxmot\__init__.py
# ['BoostTrack', 'BotSort', 'ByteTrack', 'DeepOcSort', 'HybridSort', 'OcSort', 'ReID', 'SFSORT', 'StrongSort', 'TRACKERS', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'create_tracker', 'engine', 'get_tracker_config', 'motion', 'reid', 'track', 'trackers', 'utils']
